# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("student_data.csv")

# %%
df1
# Out:
#     id  gender  instagram_followers  linkedin_con  texts_yesterday  \
# 0    1    male                  0.0         642.0             47.0
# 1    2  female                155.0         157.0            150.0
# 2    3  female                169.0         119.0             20.0
# 3    4    male                  NaN         150.0            100.0
# 4    5    male                 25.0         120.0            420.0
# 5    6    male                  0.0         187.0             20.0
# 6    7  female                  NaN           NaN              NaN
# 7    8  female                203.0         203.0            143.0
# 8    9  female                  NaN           NaN              NaN
# 9   10    male                126.0         119.0             85.0
# 10  11    male                  0.0         171.0            150.0
# 11  12    male                184.0        1000.0              NaN
# 12  13  female                131.0         399.0             27.0
# ...

# %%
gender = df1["gender"].value_counts()

# %%
gender.plot(kind="bar")

# %%
pd.crosstab(df1.gender, df1.like_tech, normalize=True)
# Out:
# like_tech     Agree  Strongly agree  Undecided
# gender
# female     0.375000            0.00   0.000000
# male       0.333333            0.25   0.041667

# %%
sns.catplot(x="gender", y="apps_phone", kind="bar", data=df1)

# %%
sns.catplot(x="gender", kind="count", data=df1);

# %%
pd.crosstab(df1.gender, df1.os_phone, normalize=True)
# Out:
# os_phone   Android       iOS
# gender
# female    0.173913  0.173913
# male      0.391304  0.260870

# %%
df1["os_phone"] = df1["os_phone"].str.replace("IOS","iOS")

# %%
sns.catplot(x="gender", hue="os_phone", kind="count", data=df1);
